# %%
import pandas as pd
import os

# %%
mops_df = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'SHADOW_MOPs.csv'))

# %%
mops_df
# Out:
#     Flight_Number   Lead_Pilot  Scenario_within_flight Scenario_Type  \
# 0               2      Grimmer                       1             C
# 1               2      Grimmer                       2             C
# 2               2      Grimmer                       3             D
# 3               3      Grimmer                       1             C
# 4               3      Grimmer                       2             C
# 5               3      Grimmer                       3             D
# 6               1  Fleischmann                       1             C
# 7               1  Fleischmann                       2             C
# 8               1  Fleischmann                       3             D
# 9               1      Grimmer                       1             C
# 10              1      Grimmer                       2             D
# 11              1      Grimmer                       3             C
# 12              2  Fleischmann                       1             C
# ...
